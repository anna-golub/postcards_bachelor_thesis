# %% [markdown]
# # Чтение данных

# %%
import pandas as pd

# %% [markdown]
# Читаем таблицу

# %%
# data = pd.read_csv("postcards_table.csv", sep=',')
data = pd.read_csv("Расшифровка открыток (основная база).csv", sep=';')

# %%
data.head()
# Out:
#                                                 Pic_url_1 Pic_url_2  \
# 0  0.0       https://forum.vgd.ru/file.php?fid=5476&key=0         0
# 1  1.0       https://forum.vgd.ru/file.php?fid=5491&key=0       NaN
# 2  2.0       https://forum.vgd.ru/file.php?fid=5492&key=0         0
# 3  3.0  https://forum.vgd.ru/file.php?fid=20890&key=19...         0
# 4  4.0  https://forum.vgd.ru/file.php?fid=20894&key=16...         0
#
#   Разрешение на публикацию   Источник Была ли открытка отправлена по почте  \
# 0      Разрешаю публикацию  Форум VGD                                   Да
# 1      Разрешаю публикацию  Форум VGD                              Не знаю
# 2      Разрешаю публикацию  Форум VGD                              Не знаю
# 3      Разрешаю публикацию  Форум VGD                              Не знаю
# 4      Разрешаю публикацию  Форум VGD                              Не знаю
#
#   Название коллекции (если вы хотите подпись на сайте). Например, личная коллекция Василия Иванова.  \
# ...

# %% [markdown]
# Выбираем открытки с проблемой "Большие поля"

# %%
data = data[data["Проблема"] == "Большие поля"]
data
# Out:
#                                                       Pic_url_1  \
# 952    952.0  https://storage.yandexcloud.net/postcards/1Crc...
# 966    966.0  https://forum.vgd.ru/file.php?fid=192315&key=3...
# 1024  1024.0  https://forum.vgd.ru/file.php?fid=210056&key=9...
# 1155  1155.0  https://forum.vgd.ru/file.php?fid=252341&key=6...
# 1157  1157.0  https://forum.vgd.ru/file.php?fid=252347&key=1...
# ...      ...                                                ...
# 6932  6936.0  https://storage.yandexcloud.net/postcards-muse...
# 6933  6937.0  https://storage.yandexcloud.net/postcards-muse...
# 6934  6938.0  https://storage.yandexcloud.net/postcards-muse...
# 6935  6939.0  https://storage.yandexcloud.net/postcards-muse...
# 6936  6940.0  https://storage.yandexcloud.net/postcards-muse...
#
#                                               Pic_url_2  \
# 952   https://storage.yandexcloud.net/postcards/1Zhy...
# 966                                                   0
# ...

# %%
data.columns
# Out:
# Index([' ', 'Pic_url_1', 'Pic_url_2', 'Разрешение на публикацию', 'Источник',
#        'Была ли открытка отправлена по почте',
#        'Название коллекции (если вы хотите подпись на сайте). Например, личная коллекция Василия Иванова.',
#        'Если знаете дату написания открытки - укажите (можно ориентировочную, можно не из открытки)',
#        'Знания не из открытки. Настоящее ФИО отправителя (если  в открытке недостаточно данных)',
#        'Знания не из открытки. Настоящее ФИО получателя (если  в открытке недостаточно данных)',
#        'Знания не из открытки. Место отправления (если в открытке нет, но вы знаете)',
#        'Знания не из открытки. Место получения (если в открытке нет, но вы знаете)',
#        'Комментарий или метаинформация. Укажите тут любую метаинформацию про открытку, которую считаете важной. Например, какое-то знание или история, которую нельзя восстановить по тексту открытки.',
#        'Разметчик', 'Проверяющий', 'Оценка проверяющего',
# ...

# %%
pictures = list(data["Pic_url_1"]) + list(data["Pic_url_2"])

# %% [markdown]
# # Функции для обрезки

# %%
pip install opencv-python
# Out:
#   Input In [7]
#     pip install opencv-python
#         ^
# SyntaxError: invalid syntax

# %%
from skimage import io
import cv2
import numpy as np
from PIL import Image, ImageDraw

# %% [markdown]
# ## Основная функция

# %%
#обрезчик
def crop_image(filename):
    image = io.imread(filename)
    try:
        if field_type(image) == 'white':  # белые поля
            image_cropped = corner_cropping(image)
        elif field_type(image) == 'coloured':  # цветные поля
            image_cropped = contrast_cropping(image)
        return image_cropped
    except IndexError:
        return image

# %% [markdown]
# ## Обрезка открыток с цветными полями

# %%
#обрезчик для открыток с цветными полями
def contrast_cropping(image):
    threshold = 2 ** 12
    sample_width_hor = 5
    head = 5
    n = 12
    
    height = image.shape[0]
    width = image.shape[1]
    pix = Image.fromarray(image).load()
    
    # разбиваем изображение на n интервалов по х
    # в каждом интервале ищем верхнюю границу
    # берем второе наименьшее значение (второе сверху)
    # аналогично для других границ
    
    upper = sorted([get_upper_bound(pix, i * (width // n), sample_width_hor, head, threshold, height) for i in range(1, n)])[2]
    lower = sorted([get_lower_bound(pix, i * (width // n), sample_width_hor, head, threshold, height) for i in range(1, n)])[-2]
    sample_width_vert = 5
    left = sorted([get_left_bound(pix, i * (height // n), sample_width_vert, head, threshold, width) for i in range(1, n)])[2]
    right = sorted([get_right_bound(pix, i * (height // n), sample_width_vert, head, threshold, width) for i in range(1, n)])[-2]

    frame = 15
    upper = max(upper - frame, 0)
    lower = min(lower + frame, height - 1)
    left = max(left - frame, 0)
    right = min(right + frame, width - 1)
    crop_img = image[upper: lower, left :right]
    return crop_img

# %% [markdown]
# Вспомогательные функции для `contrast_cropping`:

# %% [markdown]
# * `get_average_hor`
# i - строка
# mid - столбец (рассматриваем интервал mid - sample_width, mid + sample_width)
# pix - картинка
# => средние значения R, G, B по полоске - в строке i, столбцах (mid - sample_width, mid + sample_width)
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28698%29.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28698%29.png)

# %%
def get_average_hor(pix, i, mid, sample_width):  # average R, G, B 
    R = G = B = 0
    for k in range(mid - sample_width, mid + sample_width):
        R += pix[k, i][0] # индексирование верное, потому что pix - объект PIL Image, индексируется [x, y]
        G += pix[k, i][1]
        B += pix[k, i][2]
    R /= (2*sample_width)
    G /= (2*sample_width)
    B /= (2*sample_width)
    return R, G, B


def get_average_vert(pix, i, mid, sample_width):
    R = G = B = 0
    for k in range(mid - sample_width, mid + sample_width):
        R += pix[i, k][0]
        G += pix[i, k][1]
        B += pix[i, k][2]
    R /= (2*sample_width)
    G /= (2*sample_width)
    B /= (2*sample_width)
    return R, G, B

# %% [markdown]
# * `delta`
# сравниваем два набора средних R, G, B (по полоске и по прямоугольнику от границы изображения до этой полоски)
# R, G, B - то, что возвращают `get_average_hor` / `get_average_vert`
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28700%29.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28700%29.png)

# %%
def delta(R, G, B, colours):
    return (colours[0] - R) ** 2 + (colours[1] - G) ** 2 + (colours[2] - B) ** 2

# %% [markdown]
# * `get_upper_bound` --- ищем верхнюю границу полей
# аналогично - другие границы

# %%
def get_upper_bound(pix, mid, sample_width, head, threshold, height):
    # считаем средние R, G, B по прямоугольнику head (строки от 0 до head, столбцы mid - sample_width, mid + sample_width)
    R = B = G = 0
    for i in range(head):
        average = get_average_hor(pix, i, mid, sample_width)
        R += average[0]
        G += average[1]
        B += average[2]
    R /= head
    G /= head
    B /= head
    
    H = 0  # возвращаемое значение - верхняя граница картинки, которую хотим сохранить
    for i in range(head, height):  # идем вниз от прямоугольника
        average = get_average_hor(pix, i, mid, sample_width)  # среднее по текущей полоске
        if delta(R, G, B, average) > threshold:  # если разница у этой полоски
            if delta(R, G, B, get_average_hor(pix, i + 1, mid, sample_width)) > threshold:  # и у следующей больше порога
                H = i  # по этой полоске - граница полей
                break
    return H


def get_lower_bound(pix, mid, sample_width, head, threshold, height):
    R = B = G = 0
    H = 0
    for i in range(head):
        average = get_average_hor(pix, height - i - 1, mid, sample_width)
        R += average[0]
        G += average[1]
        B += average[2]
    R /= head
    G /= head
    B /= head
    for i in range(height - 1, 0, -1):
        average = get_average_hor(pix, i, mid, sample_width)
        if delta(R, G, B, average) > threshold:
            if delta(R, G, B, get_average_hor(pix, i - 1, mid, sample_width)) > threshold:
                H = i
                break
    return H
    

def get_left_bound(pix, mid, sample_width, head, threshold, width):
    R = B = G = 0
    H = 0
    for i in range(head):
        average = get_average_vert(pix, i, mid, sample_width)
        R += average[0]
        G += average[1]
        B += average[2]
    R /= head
    G /= head
    B /= head
    for i in range(head, width):
        average = get_average_vert(pix, i, mid, sample_width)
        if delta(R, G, B, average) > threshold:
            if delta(R, G, B, get_average_vert(pix, i + 1, mid, sample_width)) > threshold:
                H = i
                break
    return H


def get_right_bound(pix, mid, sample_width, head, threshold, width):
    R = B = G = 0
    H = 0
    for i in range(head):
        average = get_average_vert(pix, width - i - 1, mid, sample_width)
        R += average[0]
        G += average[1]
        B += average[2]
    R /= head
    G /= head
    B /= head
    for i in range(width - 1, 0, -1):
        average = get_average_vert(pix, i, mid, sample_width)
        if delta(R, G, B, average) > threshold:
            if delta(R, G, B, get_average_vert(pix, i - 1, mid, sample_width)) > threshold:
                H = i
                break
    return H

# %% [markdown]
# ## Обрезка открыток с белыми полями
# https://docs.opencv.org/4.x/dc/d0d/tutorial_py_features_harris.html

# %%
def corner_cropping(image):
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    gray = np.float32(gray)
    dst = cv2.cornerHarris(gray,12,3,0.00001)
    #result is dilated for marking the corners, not important
    dst = cv2.dilate(dst,None)

    height = image.shape[0]
    width = image.shape[1]
    frame = 15
    rows = np.where(np.any(dst>0.005*dst.max(), axis=1))  # список строк, где м. б. углы
    upper = max(rows[0][0] - frame, 0)  # верхняя строка, но страхуемся на frame пикселей
    lower = min(rows[0][-1] + frame, height - 1)
    columns = np.where(np.any(dst>0.005*dst.max(), axis=0))
    left = max(columns[0][0] - frame, 0)
    right = min(columns[0][-1] + frame, width - 1)
    image_cropped = image[upper :lower, left:right]
    return image_cropped

# %% [markdown]
# ## Определитель типа полей

# %%
def field_type(image):
    left_upper = is_white(image[:20, :20])
    right_upper = is_white(image[:20, -20:])
    left_lower = is_white(image[-20:, :20])
    right_lower = is_white(image[-20:, -20:])
    if left_upper+right_upper+left_lower+right_lower > 1:
        return "white"
    else:
        return "coloured"

#проверка того, наколько белый прямоугольник
def is_white(image):
    height = image.shape[0]
    width = image.shape[1]
    s = 0
    for i in range(height):
        for j in range(width):
            R = image[i][j][0]
            G = image[i][j][2]
            B = image[i][j][1]
            if R > 150 and B > 150 and G > 150:
                s += 1
    if s/(height*width) > 0.9:
        return 1
    else:
        return 0

# %% [markdown]
# ## Пример работы

# %% [markdown]
# Пример: белые поля

# %%
filename = 'examples/auction-1422-0.jpg'
orig = Image.open(filename)
orig
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=576x768 at 0x1AFB03CA460>

# %%
cropped = crop_image(filename)
Image.fromarray(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=540x712 at 0x1AFB03CAD90>

# %% [markdown]
# Пример: цветные поля

# %%
filename = 'examples/auction-1395-0.jpg'
orig = Image.open(filename)
orig
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=576x768 at 0x1AFAE3F4D30>

# %%
cropped = crop_image(filename)
Image.fromarray(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=506x706 at 0x1AFAE26C400>

# %% [markdown]
# Обрабатываем картинки и записываем в архив

# %%
import zipfile

# %%
zipf = zipfile.ZipFile('cropped_images.zip', 'w', zipfile.ZIP_DEFLATED)

for i in range(len(pictures)):
    filename = pictures[i].replace(" ", "%20")
    image = cv2.cvtColor(crop_image(filename), cv2.COLOR_BGR2RGB)
    retval, buf = cv2.imencode('.jpg', image)
    zipf.writestr(str(i)+'.jpg', buf)

zipf.close()

# %%
numbers = np.arange(len(pictures))
links = pd.DataFrame({'number': numbers, 'link': pictures}, columns=['number', 'link'])
links.to_excel("links_to_pictures.xlsx")
